# %% [markdown]
# $$\documentclass{article}
# \usepackage{amsmath, amssymb, amsfonts}
# \usepackage{bm}
#
# \begin{document}
#
# Anta at
# \[
# X \sim \mathcal{N}\Big(\mu_X,\, \Sigma_X\Big), \quad \text{der} \quad
# \mu_X = \begin{pmatrix} 0 \\ 2 \end{pmatrix} \quad \text{og} \quad
# \Sigma_X = \begin{pmatrix} 3 & 1 \\ 1 & 3 \end{pmatrix}.
# \]
# Vi definerer
# \[
# Y = \begin{pmatrix} Y_1 \\ Y_2 \end{pmatrix} = A\,X, \quad \text{der} \quad
# A = \begin{pmatrix} \frac{1}{\sqrt{2}} & -\frac{1}{\sqrt{2}} \\[1mm] \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix}.
# \]
#
# \bigskip
#
# \textbf{(a) Forventningsvektor for \(Y\):}
#
# Vi bruker formelen
# \[
# \mu_Y = A\,\mu_X.
# \]
# Dermed får vi:
# \[
# \mu_Y = \begin{pmatrix} \frac{1}{\sqrt{2}} & -\frac{1}{\sqrt{2}} \\[1mm] \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix}
# \begin{pmatrix} 0 \\ 2 \end{pmatrix}
# = \begin{pmatrix} \frac{1}{\sqrt{2}} \cdot 0 + \left(-\frac{1}{\sqrt{2}}\right) \cdot 2 \\[1mm] \frac{1}{\sqrt{2}} \cdot 0 + \frac{1}{\sqrt{2}} \cdot 2 \end{pmatrix}
# = \begin{pmatrix} -\frac{2}{\sqrt{2}} \\[1mm] \frac{2}{\sqrt{2}} \end{pmatrix}
# = \begin{pmatrix} -\sqrt{2} \\[1mm] \sqrt{2} \end{pmatrix}.
# \]
#
# \bigskip
#
# \textbf{(b) Kovariansmatrise for \(Y\):}
#
# Kovariansmatrisen til \(Y\) beregnes som:
# \[
# \Sigma_Y = A\,\Sigma_X\,A^\top,
# \]
# der
# \[
# \Sigma_X = \begin{pmatrix} 3 & 1 \\ 1 & 3 \end{pmatrix}.
# \]
# Utregningen gir:
# \[
# \Sigma_Y = \begin{pmatrix} 2 & 0 \\ 0 & 4 \end{pmatrix}.
# \]
#
# \bigskip
#
# \textbf{(c) Fordeling av \(Y\) og uavhengighet:}
#
# Siden \(X\) er bivariate normal og \(Y = A\,X\) er en lineær transformasjon av \(X\), er også \(Y\) normalfordelt:
# \[
# Y \sim \mathcal{N}\left(\begin{pmatrix} -\sqrt{2} \\ \sqrt{2} \end{pmatrix},\, \begin{pmatrix} 2 & 0 \\ 0 & 4 \end{pmatrix}\right).
# \]
# Kovariansmatrisen \(\Sigma_Y\) er diagonal, noe som innebærer at \(Y_1\) og \(Y_2\) er ukorrelert. For normalfordelte variable betyr ukorrelasjon at de også er uavhengige.
#
# \end{document}$$

# %% [markdown]
# # Oppgave (a)
#
# Anta at
# $$
# X \sim \mathcal{N}\Big(\mu_X,\, \Sigma_X\Big), \quad \text{der} \quad
# \mu_X = \begin{pmatrix} 0 \\ 2 \end{pmatrix} \quad \text{og} \quad
# \Sigma_X = \begin{pmatrix} 3 & 1 \\ 1 & 3 \end{pmatrix}.
# $$
#
# Vi definerer
# $$
# Y = \begin{pmatrix} Y_1 \\ Y_2 \end{pmatrix} = A\,X, \quad \text{der} \quad
# A = \begin{pmatrix} \frac{1}{\sqrt{2}} & -\frac{1}{\sqrt{2}} \\[1mm] \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix}.
# $$
#
# **Finne forventningsvektoren for $Y$:**
#
# Siden $Y = A\,X$ gjelder
# $$
# \mu_Y = A\,\mu_X.
# $$
#
# Vi setter inn:
# $$
# \mu_Y = \begin{pmatrix} \frac{1}{\sqrt{2}} & -\frac{1}{\sqrt{2}} \\[1mm] \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix}
# \begin{pmatrix} 0 \\ 2 \end{pmatrix}
# = \begin{pmatrix} -\sqrt{2} \\[1mm] \sqrt{2} \end{pmatrix}.
# $$
#
# **Finne kovariansmatrisen for $Y$:**
#
# Kovariansmatrisen for $Y$ er gitt ved
# $$
# \Sigma_Y = A\,\Sigma_X\,A^\top.
# $$
#
# Med
# $$
# \Sigma_X = \begin{pmatrix} 3 & 1 \\ 1 & 3 \end{pmatrix}
# \quad \text{og} \quad
# A = \begin{pmatrix} \frac{1}{\sqrt{2}} & -\frac{1}{\sqrt{2}} \\[1mm] \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \end{pmatrix},
# $$
#
# $$
# \Sigma_Y = (A\,\Sigma_X) A^\top =
# \begin{pmatrix}
# \sqrt{2} & -\sqrt{2} \\
# 2\sqrt{2} & 2\sqrt{2}
# \end{pmatrix}
# \begin{pmatrix}
# \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\
# -\frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}}
# \end{pmatrix}.
# $$
#
# Dermed har vi:
# $$
# \Sigma_Y = \begin{pmatrix} 2 & 0 \\ 0 & 4 \end{pmatrix}.
# $$
#
# **Fordeling av $Y$ og uavhengighet:**
#
# Siden $X$ er bivariate normal, er den lineære transformasjonen
# $$
# Y = A\,X
# $$
# også normalfordelt, med
# $$
# Y \sim \mathcal{N}\left(\mu_Y,\, \Sigma_Y\right)
# = \mathcal{N}\left(\begin{pmatrix} -\sqrt{2} \\ \sqrt{2} \end{pmatrix},\, \begin{pmatrix} 2 & 0 \\ 0 & 4 \end{pmatrix}\right).
# $$
#
# Siden kovariansmatrisen $\Sigma_Y$ er diagonal, er $Y_1$ og $Y_2$ ukorrelert. For normalfordelte variabler betyr dette at de også er uavhengige.
#
# # Oppgave (b)
#
# La $X$ være en bivariabel normalfordelt stokastisk variabel med tetthetsfunksjon $f$, middelverdi $\mu$ og kovariansmatrise $\Sigma$. Nivåkurvene til $f$ er gitt ved alle $x$ som tilfredsstiller
# $$
# (x - \mu)^\top \Sigma^{-1} (x - \mu) = b,
# $$
#
# $\Sigma$ kan dekomponeres som
# $$
# \Sigma = V\,\Lambda\,V^\top,
# $$
# der $\Lambda = \mathrm{diag}(\lambda_1,\lambda_2)$ inneholder egenverdiene og $V$ inneholder de tilhørende egenvektorene som kolonner. Egenvektorene bestemmer retningen på ellipsens hovedakser. Egenverdiene bestemmer lengden på halvaksene i de nye koordinatene der $\Sigma$ er diagonal.
#
# **Halvaksenes lengder**
#
# I en egenvektor-basis blir nivåkurven
# $$
# (x - \mu)^\top \Sigma^{-1} (x - \mu) = b
# $$
# til
# $$
# y^\top \Lambda^{-1} y = b,
# $$
# hvor $y = V^\top (x - \mu)$. Siden $\Lambda = \mathrm{diag}(\lambda_1, \lambda_2)$, har vi
# $$
# \frac{y_1^2}{\lambda_1} + \frac{y_2^2}{\lambda_2} = b.
# $$
#
# Dette beskriver en ellipse med halvaksene
# $$
# \sqrt{\lambda_1\,b}
# \quad\text{og}\quad
# \sqrt{\lambda_2\,b}.
# $$
#
# For figuren kan vi da hente ut halvlengdene ved å ta
# $$
# \sqrt{4.6 \times 4} \approx 4.29,
# $$
# $$
# \sqrt{4.6 \times 2} \approx 3.03.
# $$
#
#  Under ser vi bilde fra oppgaven tegnet med en oransj halvlengde og en rosa halvlengde. Og vinklene deres er reprensivt hentet fra deres tilhørende egenvektor.
#
# ![image.png](attachment:image.png)
#
# **Kobling til $\chi^2$-fordelingen og sannsynlighet**
#
# For en bivariabel normalfordeling $X \sim \mathcal{N}(\mu, \Sigma)$ er den kvadratiske formen
# $$
# Q = (X - \mu)^\top \Sigma^{-1} (x - \mu)
# $$
# fordelt som $\chi^2_2$. Dermed får vi
# $$
# P\Bigl( (X - \mu)^\top \Sigma^{-1} (X - \mu) \le b \Bigr)
# = F_{\chi^2_2}(b),
# $$
# hvor $F_{\chi^2_2}$ er fordelingsfunksjonen til $\chi^2_2$.
#
# **Sannsynligheten for å ligge innenfor en gitt ellipse**
#
# $$
# P\Bigl( (X - \mu)^\top \Sigma^{-1}(X - \mu) \le b \Bigr)
# = F_{\chi^2_2}(b).
# $$
#
# Hvis for eksempel $b = 4.605$, tilsvarer dette $\chi^2_2$-kvantilen for 90\%. Da er
# $$
# P\Bigl( (X - \mu)^\top \Sigma^{-1}(X - \mu) \le 4.605 \Bigr)
# \approx 0.90.
# $$

# %% [markdown]
# test

# %% [markdown]
# celle nummer 3

# %% [markdown]
# $$
#
# \begin{equation}
#
#     a^2+b^2 = c^2
#
# \end{equation}
# $$

# %% [markdown]
# Skriver et avsnitt for å sjekke at det fngerer

# %% [markdown]
# test av sync til jo

# %% [markdown]
# Enda en test av sync til Jo

# %%
for i in range(5): # en liten test loop, by copilot ofc xD 
    print(i)
